# %% [markdown]
# ## **Spoiler: no partitioning because of problems with the data**
#
# ❌ Steps to achive our goal "Article reproduction":
#
# 1. Download all fasta for genes COI and 18S
# 2. Sequnces alignment separately for 2 genes (MAFFT)
# 3. Check the alignments (Ugene)
# 4. Using Trimal for trimming the alignments if necessary
# 5. Use IQTree to get the right model for each gene
# 6. Using FASconCAT-G to concatenate 2 genes
# 7. Use explanation from [IQTree website](http://www.iqtree.org/doc/Complex-Models) to get the tree with partitioning
# 8. Visualize the tree
#
# Additional part:
#
# *   Use species only with the rearrangements to get the close up on it (repeat the previous steps but only with this species)
# *   To visualize the tree add the metadata
#
#
# > I guess it would be better to use different collab motebooks for different parts of the work ("Downloading data", "General tree reconstraction" and "Rearrangements tree")
#
# ---
#
# > We wanted to use partitioning for this task but the problem is data:
#
# *   18S: whole genome downloading (too big files) 33/215
# *   28S: whole genome downloading (too big files) 88/215
# *   COI: only one which is presented for all species
# *   ITS1: 16/215
# *   Cytb: 62/215 mitochondrion, complete genome
#
# ---
#
# **No partitioning then** 😞

# %% [markdown]
# ## **General tree reconstruction**
#
# **Steps to achive our goal "Article reproduction":**
#
# 1. Download all fasta for gene COI ("Downloading_data" notebook)
# 2. Sequnces alignment (MAFFT)
# 3. Check the alignments (Ugene)
# 4. Using Trimal for trimming the alignments if necessary (and it's necessary)
# 5. Check outgroup IDs
# 6. Use IQTree to get the tree (outgroup!)
# 7. Rename the tree ("Downloading_data" notebook)
# 8. Visualize the tree
#
# Additional part:
#
# *   Get the metadata
# *   To visualize the tree add the metadata
# *   Explain rearrangements

# %% [markdown]
# ## **Step 1. Alignment + trimming**
#
# We are going to use mafft for sequence alignment and Trimal to trimm it then.
#
# > Since we have complete mitochondrial genomes instead of one COI gene for some species this part with trimming is necessary.

# %%
# %%capture
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local

# %% [markdown]
# **1.1 Sequnces alignment**

# %%
# %%capture
# !apt-get install mafft

# %%
# !mafft --auto COI_sequences.fasta > COI_aligned.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#
# There are 10 ambiguous characters.
#   201 / 215
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   210 / 215
# done.
#
# Progressive alignment 1/2...
# STEP    86 / 214  f
# Reallocating..done. *alloclen = 32988
# STEP   214 / 214  f
# done.
#
# Making a distance matrix from msa..
#   200 / 215
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   210 / 215
# done.
#
# Progressive alignment 2/2...
# STEP   189 / 214  f
# Reallocating..done. *alloclen = 32863
# STEP   214 / 214  f
# done.
#
# disttbfast (nuc) Version 7.490
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %% [markdown]
# **1.2 Alignment trimming**

# %%
# !conda create -n trimal
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/trimal
#
#
#
# Proceed ([y]/n)? y
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate trimal
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !source activate trimal && conda install trimal -c conda-forge -c bioconda
# Out:
# Channels:
#  - conda-forge
#  - bioconda
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/trimal
#
#   added / updated specs:
#     - trimal
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libstdcxx-ng-14.2.0        |       h4852527_1          53 KB  conda-forge
#     trimal-1.5.0               |       h4ac6f70_1         211 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:         5.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.2.0-h69a702a_1
#   libgomp            conda-forge/linux-64::libgomp-14.2.0-h77fa898_1
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-14.2.0-h4852527_1
#   trimal             bioconda/linux-64::trimal-1.5.0-h4ac6f70_1
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages:
# libstdcxx-14.2.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
# libgcc-14.2.0        | 829 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libgomp-14.2.0       | 450 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# trimal-1.5.0         | 211 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | :   0% 0/1 [00:00<?, ?it/s]
# libstdcxx-14.2.0     | 3.7 MB    | :   0% 0.004207828296772089/1 [00:00<00:26, 26.28s/it]
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00,  7.19it/s]
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | :  30% 0.3028185934756492/1 [00:00<00:00,  2.02it/s]
#
#
#
#
#
# _openmp_mutex-4.5    | 23 KB     | :  69% 0.6936200838237162/1 [00:00<00:00,  4.42it/s]
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | : 100% 1.0/1 [00:00<00:00,  3.87it/s]
#
#
#
# libgcc-ng-14.2.0     | 53 KB     | : 100% 1.0/1 [00:00<00:00,  3.87it/s]
#
# libgomp-14.2.0       | 450 KB    | : 100% 1.0/1 [00:00<00:00,  3.46it/s]
#
# libgomp-14.2.0       | 450 KB    | : 100% 1.0/1 [00:00<00:00,  3.46it/s]
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:00<00:00,  2.40it/s]
# libgcc-14.2.0        | 829 KB    | : 100% 1.0/1 [00:00<00:00,  2.40it/s]
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00,  7.19it/s]
#
#
# trimal-1.5.0         | 211 KB    | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
#
#
# trimal-1.5.0         | 211 KB    | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | : 100% 1.0/1 [00:00<00:00,  2.04it/s]
#
#
#
#
# libstdcxx-ng-14.2.0  | 53 KB     | : 100% 1.0/1 [00:00<00:00,  2.04it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# COI trimming with -gt 0.1 param
# !source activate trimal && trimal -in COI_aligned.fasta -out COI_trimmed.fasta -gt 0.1

# %%
# !mafft --add /content/modified_mt.fa --reorder /content/COI_trimmed.fasta > /content/add_trimmed.fasta

# %% [markdown]
# > We lost this one after trimming "*DQ078424.1 Melinaea marsaeus*". and that's interesting cause its not inverted or smth seems like just lost the COI part in it.

# %% [markdown]
# ## **Step 2. Tree reconstruction**
#
# We are going to use IQTree for this and the outgroup (Trichoptera):
#
# * HM902392.1
# * OP817850.1
# * MZ629096.1
# * MZ628664.1
# * MZ627614.1

# %%
# !conda create -n iqtree
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/iqtree
#
#
#
# Proceed ([y]/n)? y
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate iqtree
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !source activate iqtree && conda install iqtree -c conda-forge -c bioconda
# Out:
# Channels:
#  - conda-forge
#  - bioconda
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/iqtree
#
#   added / updated specs:
#     - iqtree
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     iqtree-2.3.6               |       hdbdd923_0         4.0 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   iqtree             bioconda/linux-64::iqtree-2.3.6-hdbdd923_0
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.2.0-h69a702a_1
#   libgomp            conda-forge/linux-64::libgomp-14.2.0-h77fa898_1
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-14.2.0-h4852527_1
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages:
#
# done
# done
# done

# %%
# !source activate iqtree && iqtree -s COI_trimmed.fasta -m TEST -bb 1000 -nt AUTO -o HM902392.1,OP817850.1,MZ629096.1,MZ628664.1,MZ627614.1
# Out:
# IQ-TREE multicore version 2.3.6 for Linux x86 64-bit built Aug  4 2024
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor, Heiko Schmidt,
# Dominik Schrempf, Michael Woodhams, Ly Trong Nhan, Thomas Wong
#
# Host:    cbb8eb040054 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -s COI_trimmed.fasta -m TEST -bb 1000 -nt AUTO -o HM902392.1,OP817850.1,MZ629096.1,MZ628664.1,MZ627614.1
# Seed:    724479 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sun Oct 27 13:49:54 2024
# Kernel:  AVX+FMA - auto-detect threads (2 CPU cores detected)
#
# Reading alignment file COI_trimmed.fasta ... Fasta format detected
# Reading fasta file: done in 0.00446346 secs using 86.46% CPU
# Alignment most likely contains DNA/RNA sequences
# Alignment has 215 sequences with 658 columns, 524 distinct patterns
# 344 parsimony-informative, 162 singleton sites, 152 constant sites
#              Gap/Ambiguity  Composition  p-value
# Analyzing sequences: done in 0.000290618 secs using 481.4% CPU
#    1  HM902392.1     0.00%    passed     52.47%
#    2  OP817850.1     0.00%    passed     44.84%
#    3  MZ629096.1     0.91%    passed     17.05%
#    4  MZ628664.1     0.46%    passed     32.49%
#    5  MZ627614.1     0.46%    passed     14.32%
#    6  OQ563739.1     0.00%    passed     99.01%
#    7  OQ562774.1     0.00%    passed     74.72%
#    8  OQ181966.1     6.08%    passed     89.63%
#    9  OQ182072.1     0.00%    passed     79.17%
#   10  OQ183174.1     0.00%    passed     89.84%
#   11  OQ564337.1     0.00%    passed     96.34%
#   12  OQ182916.1     0.00%    passed     78.37%
#   13  OQ564147.1     0.00%    passed     98.88%
#   14  OR368811.1     0.00%    passed     88.60%
#   15  OR614510.1     0.00%    passed     96.83%
#   16  OQ564221.1     0.00%    passed     99.84%
#   17  OQ564099.1     0.00%    passed     84.34%
#   18  OQ182298.1     0.00%    passed     90.47%
#   19  OQ182974.1     0.00%    passed     73.60%
#   20  OQ563752.1     0.00%    passed     78.07%
#   21  OQ181675.1     0.00%    passed     95.88%
#   22  OQ182040.1     0.00%    passed     99.04%
#   23  OQ563910.1     0.00%    passed     98.88%
#   24  OR890456.1     0.15%    passed     81.25%
#   25  OQ563644.1     0.00%    passed     87.93%
#   26  OR369297.1     0.00%    passed     48.50%
#   27  OR890482.1    15.05%    passed     28.76%
#   28  OR367990.1     0.00%    passed     58.66%
#   29  PP728018.1     5.17%    passed     81.80%
#   30  JN266515.1     0.00%    passed     85.41%
#   31  MN387650.1     0.00%    passed     73.73%
#   32  MF049944.1     6.53%    passed     89.71%
#   33  OR890504.1     0.15%    passed     47.39%
#   34  OR890505.1     5.93%    passed     66.71%
#   35  OQ564019.1     0.00%    passed     52.68%
#   36  OQ563365.1     0.00%    passed     60.83%
#   37  GU655892.1     0.00%    passed     63.74%
#   38  JN279253.1     0.00%    passed     30.85%
#   39  OR369609.1     0.00%    passed     88.41%
#   40  HM405738.1     3.04%    passed     78.05%
#   41  HM405744.1     2.28%    passed     80.93%
#   42  OR890530.1     7.45%    passed     65.85%
#   43  PQ329533.1     0.00%    passed     38.11%
#   44  OQ181924.1     1.67%    passed     61.52%
#   45  OR890548.1    20.06%    passed     63.99%
#   46  OQ563713.1     0.00%    passed     66.05%
#   47  OR368842.1     0.00%    passed     89.53%
#   48  OQ564309.1     0.00%    passed     80.28%
#   49  OQ562769.1     0.00%    passed     63.42%
#   50  NC_023212.1    0.00%    passed     77.71%
#   51  OR890569.1     7.90%    passed     87.08%
#   52  OQ181619.1     0.00%    passed     91.05%
#   53  OR890571.1     7.60%    passed     77.03%
#   54  OR369168.1     0.00%    passed     75.87%
#   55  OQ564235.1     0.00%    passed     93.18%
#   56  HM914048.1     0.00%    passed     95.92%
#   57  OR890620.1     6.08%    passed     87.46%
#   58  OQ563650.1     0.00%    passed     98.70%
#   59  OQ562624.1     0.00%    passed     84.20%
#   60  OR369643.1     0.00%    passed     41.80%
#   61  OR890700.1     0.15%    passed     77.95%
#   62  OQ563890.1     0.00%    passed     55.11%
#   63  KP007712.1     0.00%    passed     84.48%
#   64  OQ563604.1     0.00%    passed     61.67%
#   65  KY000412.1     0.00%    passed     97.65%
#   66  NC_027156.1    0.00%    passed     88.04%
#   67  OQ562126.1     0.00%    passed     76.34%
#   68  HM871300.1     0.00%    passed     89.55%
#   69  HQ977510.1     0.00%    passed     84.24%
#   70  HM876642.1     0.00%    passed     97.15%
#   71  OR369635.1     0.00%    passed     99.01%
#   72  MH286153.1     7.14%    passed     64.24%
#   73  PQ298449.1     0.00%    passed     79.73%
#   74  OQ562385.1     0.00%    passed     76.11%
#   75  OQ182417.1     0.00%    passed     99.01%
#   76  OQ564211.1     0.00%    passed     55.24%
#   77  OR369411.1     0.00%    passed     74.09%
#   78  OR368897.1     0.00%    passed     25.68%
#   79  OQ563635.1     0.00%    passed     84.85%
#   80  OQ563450.1     0.00%    passed     72.23%
#   81  OR369281.1     0.00%    passed     93.56%
#   82  OR890702.1     4.10%    passed     48.28%
#   83  OR890742.1     6.99%    passed     26.43%
#   84  OR890752.1     7.45%    passed     93.43%
#   85  GU654971.1     0.00%    passed     96.43%
#   86  MN621055.1     0.00%    passed     68.23%
#   87  OR367879.1     0.00%    passed     72.62%
#   88  OR369033.1     0.00%    passed     45.66%
#   89  OR369420.1     0.00%    passed     55.28%
#   90  OQ564024.1     0.00%    passed     98.61%
#   91  OQ563661.1     0.00%    passed     58.49%
#   92  OQ182321.1     0.00%    passed     53.90%
#   93  OR890766.1     7.60%    passed     88.84%
#   94  OQ182387.1     0.00%    passed     90.65%
#   95  OR890773.1     3.80%    passed     27.99%
#   96  NC_014806.1    0.00%    passed     97.95%
#   97  OQ562738.1     0.00%    passed     90.69%
#   98  OR369690.1     0.00%    passed     85.72%
#   99  OQ563625.1     0.00%    passed     64.03%
#  100  OQ563057.1     0.00%    passed     88.71%
#  101  OR614532.1    15.50%    passed     94.78%
#  102  OY776805.1    42.86%    passed     69.28%
#  103  MK779614.1     0.00%    passed     79.92%
#  104  OQ562034.1     0.00%    passed     97.51%
#  105  OR890786.1    19.30%    passed     64.52%
#  106  HM377870.1     0.00%    passed     68.77%
#  107  OR890795.1     0.61%    passed     96.71%
#  108  JN286946.1    11.70%    passed     60.08%
#  109  OR369505.1     0.00%    passed     83.38%
#  110  OR369611.1     0.00%    passed     65.14%
#  111  OQ564330.1     0.00%    passed     78.96%
#  112  JN678068.1     0.00%    passed     83.77%
#  113  OQ563939.1     0.00%    passed     92.21%
#  114  OQ562780.1     0.00%    passed     34.62%
#  115  OR368924.1     4.71%    passed     97.74%
#  116  OR890798.1     7.60%    passed     96.29%
#  117  OR890801.1     7.45%    passed     63.24%
#  118  OQ563937.1     0.00%    passed     96.00%
#  119  OR890817.1     0.30%    passed     78.80%
#  120  MF054380.1     0.61%    passed     96.65%
#  121  KX230819.1    41.95%    passed     41.99%
#  122  OR890821.1     8.36%    passed     94.10%
#  123  OR890826.1     0.15%    passed     96.86%
#  124  OR369602.1     0.00%    passed     98.92%
#  125  OQ564149.1     0.00%    passed     98.11%
#  126  OR890860.1     2.89%    passed     68.95%
#  127  PQ298649.1     0.00%    passed     98.21%
#  128  OR891252.1     2.89%    passed     71.03%
#  129  OR891256.1     7.45%    passed     72.82%
#  130  OR368648.1     0.00%    passed     36.71%
#  131  OQ563675.1     0.00%    passed     88.08%
#  132  HQ568342.1     3.04%    passed     54.88%
#  133  OR890957.1    36.63%    passed     73.95%
#  134  OQ182619.1     0.00%    passed     48.34%
#  135  HQ953226.1     0.00%    passed     87.02%
#  136  OQ564348.1     0.00%    passed     75.66%
#  137  OR890980.1    36.63%    passed     86.51%
#  138  DQ078424.1    12.92%    failed      0.00%
#  139  KU892715.1     5.32%    passed     69.75%
#  140  OR891065.1     0.30%    passed     92.77%
#  141  OR890992.1     0.30%    passed     98.63%
#  142  OQ563515.1     0.00%    passed     91.94%
#  143  OQ182001.1     7.14%    failed      0.14%
#  144  OQ563808.1     0.00%    passed     87.41%
#  145  OQ564173.1     0.00%    passed     97.82%
#  146  OQ564350.1     0.00%    passed     92.79%
#  147  OQ564303.1     0.00%    passed     94.64%
#  148  OQ562882.1     0.00%    passed     95.96%
#  149  MT324064.1     0.00%    passed     51.27%
#  150  OQ182983.1     0.00%    passed     80.50%
#  151  OQ563516.1     0.00%    passed     67.46%
#  152  OQ563874.1     0.00%    passed     85.41%
#  153  OQ564204.1     0.00%    passed     79.33%
#  154  OQ564195.1     0.00%    passed     48.91%
#  155  OQ564004.1     0.00%    passed     25.89%
#  156  OR891101.1     0.15%    passed     53.40%
#  157  OR890450.1     1.98%    passed     98.57%
#  158  OR891109.1     8.21%    passed     67.57%
#  159  OQ564282.1     0.00%    passed     68.89%
#  160  MH850976.1     0.00%    passed     97.96%
#  161  OR614726.1     0.00%    passed     88.24%
#  162  OR369569.1     0.00%    passed     76.12%
#  163  OQ562331.1     0.00%    passed     63.62%
#  164  OQ563254.1     0.00%    passed     99.97%
#  165  OQ182700.1     0.00%    passed     94.16%
#  166  OR891111.1     7.45%    passed     86.86%
#  167  OQ563225.1     0.00%    passed     70.48%
#  168  OR891117.1    20.06%    passed     79.25%
#  169  OR369180.1     3.04%    passed     67.73%
#  170  OQ563925.1     0.00%    passed     98.95%
#  171  OQ182745.1     0.00%    passed     51.16%
#  172  OQ563991.1     0.00%    passed     80.16%
#  173  OR368942.1     0.00%    passed     30.32%
#  174  OQ564139.1     0.00%    passed     99.53%
#  175  OQ563986.1     0.00%    passed     98.79%
#  176  OR891167.1     7.60%    passed     57.08%
#  177  OR891179.1     7.29%    passed     92.74%
#  178  OR891202.1     7.90%    passed     87.59%
#  179  OR891213.1     0.46%    passed     65.49%
#  180  OQ564031.1     0.00%    passed     97.92%
#  181  OR891280.1     9.57%    passed     90.98%
#  182  OQ564246.1     0.00%    passed     96.56%
#  183  OQ563498.1     0.00%    passed     26.22%
#  184  OR891316.1     7.45%    passed     84.61%
#  185  OQ562561.1     0.00%    passed     74.50%
#  186  OR369507.1     0.00%    passed     68.13%
#  187  OL534370.1     0.00%    failed      0.14%
#  188  JN279255.1     0.00%    passed     60.80%
#  189  OQ564168.1     0.00%    passed     91.71%
#  190  OQ563098.1     0.00%    passed     98.79%
#  191  OQ564362.1     0.00%    passed     94.23%
#  192  ON704401.1    26.14%    failed      0.03%
#  193  NC_022676.1    0.00%    passed     92.21%
#  194  HM871659.1     0.00%    passed     94.16%
#  195  GU706630.1     0.00%    passed     18.72%
#  196  JN279252.1     0.00%    passed     35.28%
#  197  KP253407.1     0.00%    passed     17.56%
#  198  OR369499.1     0.00%    passed     55.31%
#  199  OQ563584.1     0.00%    passed     85.23%
#  200  OQ564245.1     0.00%    passed     67.23%
#  201  OR891397.1     6.84%    passed     70.73%
#  202  JF848487.1     0.00%    passed     50.90%
#  203  OQ564107.1     0.00%    passed     76.00%
#  204  OR891400.1     2.89%    passed     86.57%
#  205  OR891401.1     0.30%    passed     99.80%
#  206  OQ563116.1     0.00%    passed     34.71%
#  207  OQ564124.1     0.00%    passed     95.45%
#  208  HM872583.1     0.00%    passed     93.54%
#  209  OQ563838.1     0.00%    passed     97.58%
#  210  HM405698.1     0.15%    passed     84.19%
#  211  HQ955534.1     0.00%    passed     36.75%
#  212  OQ182718.1     0.00%    passed     93.43%
#  213  OQ183125.1     0.00%    passed     23.57%
#  214  OQ563627.1     0.00%    passed     57.76%
#  215  MK931019.1     0.00%    passed     35.75%
# ****  TOTAL          2.46%  4 sequences failed composition chi2 test (p-value<5%; df=3)
#
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.050 seconds
# Measuring multi-threading efficiency up to 2 CPU cores
# Increase to 10 rounds for branch lengths
# 7 trees examined
# Threads: 1 / Time: 2.037 sec / Speedup: 1.000 / Efficiency: 100% / LogL: -43886
# Threads: 2 / Time: 5.661 sec / Speedup: 0.360 / Efficiency: 18% / LogL: -43886
# BEST NUMBER OF THREADS: 1
#
# Perform fast likelihood tree search using GTR+I+G model...
# Estimate model parameters (epsilon = 5.000)
# Perform nearest neighbor interchange...
# Estimate model parameters (epsilon = 1.000)
# 1. Initial log-likelihood: -35315.063
# 2. Current log-likelihood: -35313.306
# Optimal log-likelihood: -35313.042
# Rate parameters:  A-C: 3.19120  A-G: 10.49986  A-T: 14.73314  C-G: 2.38324  C-T: 58.16208  G-T: 1.00000
# Base frequencies:  A: 0.304  C: 0.158  G: 0.146  T: 0.392
# Proportion of invariable sites: 0.183
# Gamma shape alpha: 0.475
# Parameters optimization took 2 rounds (0.504 sec)
# Time for fast ML tree search: 4.548 seconds
#
# NOTE: ModelFinder requires 16 MB RAM!
# ModelFinder will test up to 88 DNA models (sample size: 658 epsilon: 0.100) ...
#  No. Model         -LnL         df  AIC          AICc         BIC
#   1  GTR+F         43564.694    435 87999.388    89708.037    89952.192
#   2  GTR+F+I       41420.241    436 83712.482    85436.754    85669.776
#   3  GTR+F+G4      35411.014    436 71694.028    73418.300    73651.322
#   4  GTR+F+I+G4    35313.032    437 71500.064    73240.119    73461.847
#   8  SYM+I+G4      35758.531    434 72385.062    74078.246    74333.377
#  12  TVM+F+I+G4    35842.463    436 72556.926    74281.198    74514.220
#  16  TVMe+I+G4     36444.391    433 73754.782    75432.657    75698.608
#  20  TIM3+F+I+G4   35801.470    435 72472.940    74181.589    74425.744
#  24  TIM3e+I+G4    37084.913    432 75033.827    76696.547    76973.163
#  28  TIM2+F+I+G4   35459.803    435 71789.606    73498.255    73742.410
#  32  TIM2e+I+G4    36570.258    432 74004.516    75667.236    75943.852
#  36  TIM+F+I+G4    35448.204    435 71766.408    73475.057    73719.212
#  40  TIMe+I+G4     36279.933    432 73423.866    75086.586    75363.202
#  44  TPM3u+F+I+G4  36334.740    434 73537.480    75230.664    75485.795
#  48  TPM3+I+G4     37879.848    431 76621.696    78269.412    78556.543
#  52  TPM2u+F+I+G4  36010.532    434 72889.064    74582.247    74837.378
#  56  TPM2+I+G4     37104.656    431 75071.312    76719.028    77006.159
#  60  K3Pu+F+I+G4   36017.631    434 72903.263    74596.446    74851.578
#  64  K3P+I+G4      36961.306    431 74784.612    76432.329    76719.460
#  68  TN+F+I+G4     35885.255    434 72638.511    74331.694    74586.826
#  72  TNe+I+G4      37659.363    431 76180.727    77828.444    78115.574
#  76  HKY+F+I+G4    36462.496    433 73790.992    75468.867    75734.818
#  80  K2P+I+G4      38335.994    430 77531.987    79164.851    79462.345
#  84  F81+F+I+G4    37473.585    432 75811.170    77473.890    77750.506
#  88  JC+I+G4       38748.983    429 78355.967    79974.125    80281.836
# Akaike Information Criterion:           GTR+F+I+G4
# Corrected Akaike Information Criterion: GTR+F+I+G4
# Bayesian Information Criterion:         GTR+F+I+G4
# Best-fit model: GTR+F+I+G4 chosen according to BIC
#
# All model information printed to COI_trimmed.fasta.model.gz
# CPU time for ModelFinder: 46.033 seconds (0h:0m:46s)
# Wall-clock time for ModelFinder: 45.425 seconds (0h:0m:45s)
# Generating 1000 samples for ultrafast bootstrap (seed: 724479)...
#
# NOTE: 16 MB RAM (0 GB) is required!
# Estimate model parameters (epsilon = 0.100)
# Thoroughly optimizing +I+G parameters from 10 start values...
# Init pinv, alpha: 0.000, 0.521 / Estimate: 0.180, 0.477 / LogL: -35327.853
# Init pinv, alpha: 0.026, 0.521 / Estimate: 0.180, 0.478 / LogL: -35325.783
# Init pinv, alpha: 0.051, 0.521 / Estimate: 0.181, 0.478 / LogL: -35323.909
# Init pinv, alpha: 0.077, 0.521 / Estimate: 0.181, 0.478 / LogL: -35321.755
# Init pinv, alpha: 0.103, 0.521 / Estimate: 0.181, 0.477 / LogL: -35319.589
# Init pinv, alpha: 0.128, 0.521 / Estimate: 0.182, 0.476 / LogL: -35317.404
# Init pinv, alpha: 0.154, 0.521 / Estimate: 0.182, 0.475 / LogL: -35315.427
# Init pinv, alpha: 0.180, 0.521 / Estimate: 0.182, 0.475 / LogL: -35312.994
# Init pinv, alpha: 0.205, 0.521 / Estimate: 0.183, 0.474 / LogL: -35310.866
# Init pinv, alpha: 0.231, 0.521 / Estimate: 0.183, 0.473 / LogL: -35308.464
# Optimal pinv,alpha: 0.183, 0.473 / LogL: -35308.464
#
# Parameters optimization took 32.548 sec
# WARNING: Branch separating outgroup is not found
# Wrote distance file to...
# Computing ML distances based on estimated model parameters...
# Calculating distance matrix: done in 0.24184 secs using 99.53% CPU
# Computing ML distances took 0.242480 sec (of wall-clock time) 0.241351 sec (of CPU time)
# WARNING: Some pairwise ML distances are too long (saturated)
# Setting up auxiliary I and S matrices: done in 0.00178789 secs using 99.61% CPU
# Computing RapidNJ tree took 0.008131 sec (of wall-clock time) 0.010871 sec (of CPU time)
# Log-likelihood of RapidNJ tree: -35309.437
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 98 parsimony trees... 6.618 second
# Computing log-likelihood of 98 initial trees ... 4.243 seconds
# Current best score: -35308.464
#
# Do NNI search on 20 best initial trees
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 1: -35308.416
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 2: -35005.850
# Iteration 10 / LogL: -35180.433 / Time: 0h:1m:50s
# Iteration 20 / LogL: -35180.184 / Time: 0h:2m:9s
# Finish initializing candidate tree set (20)
# Current best tree score: -35005.850 / CPU time: 50.059
# Number of iterations: 20
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 22: -35000.120
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 25: -34997.312
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 27: -34992.182
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 30: -34989.924
# Iteration 30 / LogL: -34989.924 / Time: 0h:2m:25s (0h:5m:45s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 33: -34989.715
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 35: -34987.208
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 36: -34968.234
# Iteration 40 / LogL: -34987.701 / Time: 0h:2m:44s (0h:4m:52s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 41: -34965.449
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 45: -34948.555
# Iteration 50 / LogL: -34964.323 / Time: 0h:2m:59s (0h:4m:19s left)
# Log-likelihood cutoff on original alignment: -35156.033
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 58: -34944.430
# Iteration 60 / LogL: -34965.161 / Time: 0h:3m:15s (0h:4m:9s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 64: -34942.938
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 67: -34934.293
# Iteration 70 / LogL: -34950.333 / Time: 0h:3m:30s (0h:3m:51s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 75: -34930.409
# Iteration 80 / LogL: -34941.429 / Time: 0h:3m:45s (0h:3m:37s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 83: -34926.447
# Iteration 90 / LogL: -34959.567 / Time: 0h:4m:0s (0h:3m:23s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 100: -34925.577
# Iteration 100 / LogL: -34925.577 / Time: 0h:4m:15s (0h:3m:31s left)
# Log-likelihood cutoff on original alignment: -35121.744
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.878
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 103: -34923.728
# Iteration 110 / LogL: -34938.246 / Time: 0h:4m:29s (0h:3m:11s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 119: -34917.973
# Iteration 120 / LogL: -34928.829 / Time: 0h:4m:46s (0h:3m:20s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 127: -34917.388
# Iteration 130 / LogL: -34918.920 / Time: 0h:5m:0s (0h:3m:11s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 138: -34915.844
# Iteration 140 / LogL: -34917.907 / Time: 0h:5m:14s (0h:3m:9s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 149: -34913.747
# Iteration 150 / LogL: -34933.296 / Time: 0h:5m:28s (0h:3m:8s left)
# Log-likelihood cutoff on original alignment: -35121.744
# Iteration 160 / LogL: -34916.195 / Time: 0h:5m:42s (0h:2m:46s left)
# Iteration 170 / LogL: -34917.027 / Time: 0h:5m:57s (0h:2m:25s left)
# Iteration 180 / LogL: -34922.337 / Time: 0h:6m:9s (0h:2m:4s left)
# Iteration 190 / LogL: -34919.481 / Time: 0h:6m:21s (0h:1m:45s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 192: -34913.348
# Iteration 200 / LogL: -34927.033 / Time: 0h:6m:35s (0h:2m:41s left)
# Log-likelihood cutoff on original alignment: -35003.992
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.944
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 203: -34912.340
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 206: -34909.822
# Iteration 210 / LogL: -34921.449 / Time: 0h:6m:49s (0h:2m:47s left)
# Iteration 220 / LogL: -34920.971 / Time: 0h:7m:2s (0h:2m:28s left)
# Iteration 230 / LogL: -34921.042 / Time: 0h:7m:13s (0h:2m:8s left)
# Iteration 240 / LogL: -34970.333 / Time: 0h:7m:27s (0h:1m:50s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 247: -34903.396
# Iteration 250 / LogL: -34920.782 / Time: 0h:7m:40s (0h:2m:41s left)
# Log-likelihood cutoff on original alignment: -35003.992
# Iteration 260 / LogL: -34906.965 / Time: 0h:7m:53s (0h:2m:23s left)
# Iteration 270 / LogL: -34914.408 / Time: 0h:8m:7s (0h:2m:6s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 276: -34901.379
# Iteration 280 / LogL: -34920.442 / Time: 0h:8m:21s (0h:2m:36s left)
# Iteration 290 / LogL: -34913.074 / Time: 0h:8m:34s (0h:2m:19s left)
# Iteration 300 / LogL: -34907.343 / Time: 0h:8m:47s (0h:2m:2s left)
# Log-likelihood cutoff on original alignment: -35003.992
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.947
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 310 / LogL: -34945.863 / Time: 0h:9m:4s (0h:2m:25s left)
# Iteration 320 / LogL: -34919.235 / Time: 0h:9m:17s (0h:2m:8s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 327: -34901.171
# Iteration 330 / LogL: -34910.666 / Time: 0h:9m:31s (0h:2m:35s left)
# Iteration 340 / LogL: -34944.340 / Time: 0h:9m:44s (0h:2m:18s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 350: -34900.699
# Iteration 350 / LogL: -34900.699 / Time: 0h:9m:58s (0h:2m:38s left)
# Log-likelihood cutoff on original alignment: -35003.992
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 353: -34900.682
# Iteration 360 / LogL: -34906.567 / Time: 0h:10m:12s (0h:2m:26s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 363: -34899.331
# Iteration 370 / LogL: -34902.400 / Time: 0h:10m:26s (0h:2m:26s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 371: -34898.802
# Iteration 380 / LogL: -34919.450 / Time: 0h:10m:40s (0h:2m:22s left)
# Iteration 390 / LogL: -34906.041 / Time: 0h:10m:54s (0h:2m:6s left)
# Iteration 400 / LogL: -34904.629 / Time: 0h:11m:8s (0h:1m:50s left)
# Log-likelihood cutoff on original alignment: -35003.992
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.937
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 405: -34898.018
# Iteration 410 / LogL: -34904.648 / Time: 0h:11m:22s (0h:2m:28s left)
# Iteration 420 / LogL: -34907.527 / Time: 0h:11m:35s (0h:2m:11s left)
# Iteration 430 / LogL: -34902.043 / Time: 0h:11m:49s (0h:1m:56s left)
# Iteration 440 / LogL: -34902.022 / Time: 0h:12m:3s (0h:1m:40s left)
# Iteration 450 / LogL: -34908.293 / Time: 0h:12m:15s (0h:1m:24s left)
# Log-likelihood cutoff on original alignment: -35003.992
# Iteration 460 / LogL: -34901.081 / Time: 0h:12m:31s (0h:1m:9s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 465: -34897.603
# Iteration 470 / LogL: -34899.172 / Time: 0h:12m:45s (0h:2m:25s left)
# Iteration 480 / LogL: -34908.153 / Time: 0h:12m:58s (0h:2m:10s left)
# Iteration 490 / LogL: -34944.486 / Time: 0h:13m:11s (0h:1m:54s left)
# Iteration 500 / LogL: -34906.685 / Time: 0h:13m:25s (0h:1m:38s left)
# Log-likelihood cutoff on original alignment: -35003.992
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.959
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 510 / LogL: -34911.259 / Time: 0h:13m:40s (0h:2m:17s left)
# Iteration 520 / LogL: -34910.441 / Time: 0h:13m:54s (0h:2m:1s left)
# Iteration 530 / LogL: -34901.714 / Time: 0h:14m:8s (0h:1m:46s left)
# Iteration 540 / LogL: -34910.819 / Time: 0h:14m:22s (0h:1m:30s left)
# Iteration 550 / LogL: -34905.039 / Time: 0h:14m:38s (0h:1m:15s left)
# Log-likelihood cutoff on original alignment: -35003.992
# Iteration 560 / LogL: -34905.493 / Time: 0h:14m:53s (0h:1m:0s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 569: -34897.343
# Iteration 570 / LogL: -34905.523 / Time: 0h:15m:6s (0h:2m:29s left)
# Iteration 580 / LogL: -34904.584 / Time: 0h:15m:20s (0h:2m:14s left)
# Iteration 590 / LogL: -34903.834 / Time: 0h:15m:34s (0h:1m:59s left)
# Iteration 600 / LogL: -34943.647 / Time: 0h:15m:48s (0h:1m:44s left)
# Log-likelihood cutoff on original alignment: -35003.992
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.989
# NOTE: UFBoot does not converge, continue at least 100 more iterations
# Iteration 610 / LogL: -34899.381 / Time: 0h:16m:3s (0h:2m:15s left)
# Iteration 620 / LogL: -34900.377 / Time: 0h:16m:17s (0h:2m:0s left)
# Iteration 630 / LogL: -34902.559 / Time: 0h:16m:32s (0h:1m:45s left)
# Iteration 640 / LogL: -34903.097 / Time: 0h:16m:46s (0h:1m:30s left)
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 647: -34896.251
# Iteration 650 / LogL: -34908.676 / Time: 0h:17m:0s (0h:2m:25s left)
# Log-likelihood cutoff on original alignment: -35003.992
# Iteration 660 / LogL: -34904.567 / Time: 0h:17m:16s (0h:2m:10s left)
# Iteration 670 / LogL: -34901.453 / Time: 0h:17m:30s (0h:1m:55s left)
# Iteration 680 / LogL: -34901.176 / Time: 0h:17m:46s (0h:1m:40s left)
# Iteration 690 / LogL: -34917.931 / Time: 0h:18m:1s (0h:1m:25s left)
# Iteration 700 / LogL: -34918.892 / Time: 0h:18m:17s (0h:1m:10s left)
# Log-likelihood cutoff on original alignment: -35003.992
# NOTE: Bootstrap correlation coefficient of split occurrence frequencies: 0.993
# Iteration 710 / LogL: -34908.377 / Time: 0h:18m:32s (0h:2m:15s left)
# Iteration 720 / LogL: -34913.863 / Time: 0h:18m:47s (0h:2m:0s left)
# Iteration 730 / LogL: -34919.609 / Time: 0h:19m:2s (0h:1m:45s left)
# Iteration 740 / LogL: -34903.784 / Time: 0h:19m:17s (0h:1m:30s left)
# TREE SEARCH COMPLETED AFTER 748 ITERATIONS / Time: 0h:19m:29s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -34896.251
# Optimal log-likelihood: -34896.250
# Rate parameters:  A-C: 3.31727  A-G: 10.91912  A-T: 15.58074  C-G: 2.13904  C-T: 63.19989  G-T: 1.00000
# Base frequencies:  A: 0.304  C: 0.158  G: 0.146  T: 0.392
# Proportion of invariable sites: 0.182
# Gamma shape alpha: 0.467
# Parameters optimization took 1 rounds (0.152 sec)
# BEST SCORE FOUND : -34896.250
# Creating bootstrap support values...
# Split supports printed to NEXUS file COI_trimmed.fasta.splits.nex
# Total tree length: 61.946
#
# Total number of iterations: 748
# CPU time used for tree search: 1071.707 sec (0h:17m:51s)
# Wall-clock time used for tree search: 1090.348 sec (0h:18m:10s)
# Total CPU time used: 1152.308 sec (0h:19m:12s)
# Total wall-clock time used: 1170.623 sec (0h:19m:30s)
#
# Computing bootstrap consensus tree...
# Reading input file COI_trimmed.fasta.splits.nex...
# 215 taxa and 2302 splits.
# Consensus tree written to COI_trimmed.fasta.contree
# Reading input trees file COI_trimmed.fasta.contree
# Log-likelihood of consensus tree: -34899.875
# WARNING: Branch separating outgroup is not found
# WARNING: Branch separating outgroup is not found
#
# Analysis results written to:
#   IQ-TREE report:                COI_trimmed.fasta.iqtree
#   Maximum-likelihood tree:       COI_trimmed.fasta.treefile
#   Likelihood distances:          COI_trimmed.fasta.mldist
#
# Ultrafast bootstrap approximation results written to:
#   Split support values:          COI_trimmed.fasta.splits.nex
#   Consensus tree:                COI_trimmed.fasta.contree
#   Screen log file:               COI_trimmed.fasta.log
#
# Date and Time: Sun Oct 27 14:09:25 2024

# %% [markdown]
# ## **Step 3.5 Rename the species**
#
# Go to "Downloading_data" colab.

# %% [markdown]
# ## **Step 4. Tree visualisation**
#
# We are going to use [ITOl](https://itol.embl.de/) to do it.
